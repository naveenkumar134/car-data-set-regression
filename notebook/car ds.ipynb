# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# $$1. EDA$$

# %%
data=pd.read_csv("Car-details-v3.csv")
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data.shape
# Out:
# (8128, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
data=data.replace(['kmpl',''],"",regex=True)
print(data)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data['mileage']=pd.to_numeric(data['mileage'],errors="coerce")
print(data['mileage'].dtype)
# Out:
# float64

# %%
data=data.replace(['CC',''],"",regex=True)
print(data)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data['engine']=pd.to_numeric(data['engine'],errors='coerce')
print(data['engine'].dtype)
# Out:
# float64

# %%
data=data.replace(['bhp',''],"",regex=True)
print(data)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data['max_power']=pd.to_numeric(data['max_power'],errors='coerce')
print(data['max_power'].dtype)
# Out:
# float64

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00
# 3  Individual       Manual   First Owner    23.00  1396.0      90.00
# 4  Individual       Manual   First Owner    16.10  1298.0      88.20
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %%
data=data.replace(['@',''],"",regex=True)
data=data.replace(['Nm',''],"",regex=True)
data=data.replace(['kgm',''],"",regex=True)
data=data.replace(['rpm',''],"",regex=True)
print(data.head())
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00
# 3  Individual       Manual   First Owner    23.00  1396.0      90.00
# 4  Individual       Manual   First Owner    16.10  1298.0      88.20
#
#                torque  seats
# 0            190 2000    5.0
# 1       250 1500-2500    5.0
# ...

# %%
data['torque']=pd.to_numeric(data['torque'],errors='coerce')
print(data['torque'].dtype)
# Out:
# float64

# %%
data.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  8128.000000   8.128000e+03  8.128000e+03  7819.000000  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04    19.390375  1458.625016
# std       4.044249   8.062534e+05  5.655055e+04     4.001777   503.916303
# min    1983.000000   2.999900e+04  1.000000e+00     0.000000   624.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04    16.780000  1197.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04    19.300000  1248.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04    22.320000  1582.000000
# max    2020.000000   1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power      torque        seats
# count  7912.000000   34.000000  7907.000000
# mean     91.517919  402.352941     5.416719
# std      35.822499   13.719887     0.959588
# min       0.000000  400.000000     2.000000
# 25%      68.050000  400.000000     5.000000
# ...

# %%
data.isnull().sum()
# Out:
# name                0
# year                0
# selling_price       0
# km_driven           0
# fuel                0
# seller_type         0
# transmission        0
# owner               0
# mileage           309
# engine            221
# max_power         216
# torque           8094
# seats             221
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)
data
# Out:
#                                 name  year  selling_price  km_driven    fuel  \
# 145           Volvo XC40 D4 R-Design  2018        3400000      22000  Diesel
# 374   Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 413   Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 650   Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 1081  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 1100  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 1119  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 1138  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 1713  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 1828  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 2634  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# ...

# %%
data.var()
# Out:
# year             8.288770e-02
# selling_price    1.788235e+11
# km_driven        2.693137e+07
# mileage          1.360000e+00
# engine           0.000000e+00
# max_power        5.955882e+01
# torque           1.882353e+02
# seats            0.000000e+00
# dtype: float64

# %%
data.head()
# Out:
#                                 name  year  selling_price  km_driven    fuel  \
# 145           Volvo XC40 D4 R-Design  2018        3400000      22000  Diesel
# 374   Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 413   Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 650   Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 1081  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
#
#      seller_type transmission        owner  mileage  engine  max_power  \
# 145       Dealer    Automatic  First Owner     18.0  1969.0      190.0
# 374   Individual    Automatic  First Owner     18.0  1969.0      190.0
# 413   Individual    Automatic  First Owner     18.0  1969.0      190.0
# 650   Individual    Automatic  First Owner     18.0  1969.0      190.0
# 1081  Individual    Automatic  First Owner     18.0  1969.0      190.0
#
#       torque  seats
# 145    400.0    5.0
# 374    400.0    5.0
# ...

# %%
final=data.drop(['fuel','seller_type','name','transmission','owner'],axis=1)

# %%
final
# Out:
#       year  selling_price  km_driven  mileage  engine  max_power  torque  \
# 145   2018        3400000      22000     18.0  1969.0      190.0   400.0
# 374   2019        3800000      20000     18.0  1969.0      190.0   400.0
# 413   2019        3800000      20000     18.0  1969.0      190.0   400.0
# 650   2019        3800000      20000     18.0  1969.0      190.0   400.0
# 1081  2019        3800000      20000     18.0  1969.0      190.0   400.0
# 1100  2019        3800000      20000     18.0  1969.0      190.0   400.0
# 1119  2019        3800000      20000     18.0  1969.0      190.0   400.0
# 1138  2019        3800000      20000     18.0  1969.0      190.0   400.0
# 1713  2019        3800000      20000     18.0  1969.0      190.0   400.0
# 1828  2019        3800000      20000     18.0  1969.0      190.0   400.0
# 2634  2019        3800000      20000     18.0  1969.0      190.0   400.0
# 2667  2019        3800000      20000     18.0  1969.0      190.0   400.0
# ...

# %%
final.dtypes
# Out:
# year               int64
# selling_price      int64
# km_driven          int64
# mileage          float64
# engine           float64
# max_power        float64
# torque           float64
# seats            float64
# dtype: object

# %% [markdown]
# $$ 2. Statistical analysis$$

# %%
features=final.iloc[:,:-1].values
labels=final.iloc[:,-1].values

# %%
from sklearn.feature_selection import SelectKBest,chi2

# %%
for i in range(1,len(final.columns)-1):
    sel=SelectKBest(chi2,k=i)
    col=sel.fit_transform(features,labels)
    print(col)
# Out:
# [[400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [400.]
#  [480.]
#  [400.]
#  [400.]]
# [[190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [190. 400.]
#  [235. 480.]
#  [190. 400.]
#  [190. 400.]]
# [[1969.  190.  400.]
#  [1969.  190.  400.]
#  [1969.  190.  400.]
#  [1969.  190.  400.]
#  [1969.  190.  400.]
#  [1969.  190.  400.]
# ...

# %% [markdown]
# $$3. Build the model$$

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(
   features,labels,test_size=0.2
)

# %% [markdown]
# $$ 4. Training and Testing$$

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_pred,y_test))
print(classification_report(y_test,y_pred))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00         7
#
#     accuracy                           1.00         7
#    macro avg       1.00      1.00      1.00         7
# weighted avg       1.00      1.00      1.00         7
